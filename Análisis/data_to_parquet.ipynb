# %%
import pandas as pd

# %%
# abrimos archivo original
df = pd.read_csv('../Data/Data.csv', sep=';')

# %%
df
# Out:
#                             time shift crew  hour equipment equipment_type  \
# 0        2022-01-01 00:00:00.000     A   E4     0      C-04          Truck
# 1        2022-01-01 00:00:00.000     A   E4     0      C-14          Truck
# 2        2022-01-01 00:00:00.000     A   E4     0      C-15          Truck
# 3        2022-01-01 00:00:00.000     A   E4     0      C820          Truck
# 4        2022-01-01 00:00:00.000     A   E4     0      C823          Truck
# ...                          ...   ...  ...   ...       ...            ...
# 2254316  2024-02-29 00:00:00.000     B   E1    11      C934          Truck
# 2254317  2024-02-29 00:00:00.000     B   E1    11      C935          Truck
# 2254318  2024-02-29 00:00:00.000     B   E1    11      C951          Truck
# 2254319  2024-02-29 00:00:00.000     B   E1    11      C957          Truck
# 2254320  2024-02-29 00:00:00.000     B   E1    11      G126          Truck
#
#         equipment_equipment_type   total  efectivo  d_prog  ...  \
# ...

# %%
# lo guardamos como parquet
df.to_parquet('../Data/Data.parquet', index=False)
