# %% [markdown]
# ## **Capstone MDS - XGBoost**

# %% [markdown]
# #### **_Integrantes:_**
#
# 1. Evans Díaz
# 1. Felipe Ojeda
# 1. Javier Cofre
# 1. Luis Reinoso

# %%
# importar librerías
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import statsmodels.api as sm
import xgboost as xgb

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import randint, uniform
from matplotlib.ticker import EngFormatter

# %%
# función cálculo R2, RMSE y MSE
def R2_RMSE(y_true, y_pred):
  # cálculo de R2 y RMSE
  r2 = r2_score(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mse)
  
  return print('R2:',r2), print('RMSE:',rmse), print('MSE:', mse)

# %% [markdown]
# ## **_1. Lectura (carga) de los Datos_**

# %%
# importamos archivo
df = pd.read_csv('../Data/df_final_pay.csv')

# %%
# miramos el dataframe
df.head()
# Out:
#    year_2023  year_2024  month_2  month_3  month_4  month_5  month_6  month_7  \
# 0      False      False    False    False    False    False    False    False
# 1      False      False    False    False    False    False    False    False
# 2      False      False    False    False    False    False    False    False
# 3      False      False    False    False    False    False    False    False
# 4      False      False    False    False    False    False    False    False
#
#    month_8  month_9  ...  CAT 798-AC  KOM-CHQ  KOM.960E5  Kom.930E-4  \
# 0    False    False  ...         0.0      0.0       24.0        96.0
# 1    False    False  ...         0.0      0.0       24.0        96.0
# 2    False    False  ...         0.0      0.0       24.0        96.0
# 3    False    False  ...         0.0      0.0       24.0        95.0
# 4    False    False  ...         0.0      0.0       24.0        96.0
#
#    Kom.930E-4SE  Kom.930EN  Kom.930ER  Kom.930ER-MT  Kom.980E5  Komatsu AHS
# 0         395.0       96.0      240.0           0.0      132.0         24.0
# 1         396.0       96.0      240.0           0.0      132.0         24.0
# 2         394.0       96.0      240.0           0.0      132.0         24.0
# 3         396.0       96.0      240.0           0.0      132.0         24.0
# 4         395.0       96.0      240.0           0.0      132.0         24.0
#
# [5 rows x 85 columns]

# %%
# información general df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Data columns (total 85 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_2023            1567 non-null   bool
#  1   year_2024            1567 non-null   bool
#  2   month_2              1567 non-null   bool
#  3   month_3              1567 non-null   bool
#  4   month_4              1567 non-null   bool
#  5   month_5              1567 non-null   bool
#  6   month_6              1567 non-null   bool
#  7   month_7              1567 non-null   bool
#  8   month_8              1567 non-null   bool
#  9   month_9              1567 non-null   bool
#  10  month_10             1567 non-null   bool
#  11  month_11             1567 non-null   bool
#  12  month_12             1567 non-null   bool
#  13  day_2                1567 non-null   bool
#  14  day_3                1567 non-null   bool
#  15  day_4                1567 non-null   bool
#  16  day_5                1567 non-null   bool
#  17  day_6                1567 non-null   bool
#  18  day_7                1567 non-null   bool
#  19  day_8                1567 non-null   bool
#  20  day_9                1567 non-null   bool
#  21  day_10               1567 non-null   bool
#  22  day_11               1567 non-null   bool
#  23  day_12               1567 non-null   bool
#  24  day_13               1567 non-null   bool
#  25  day_14               1567 non-null   bool
#  26  day_15               1567 non-null   bool
#  27  day_16               1567 non-null   bool
#  28  day_17               1567 non-null   bool
#  29  day_18               1567 non-null   bool
#  30  day_19               1567 non-null   bool
#  31  day_20               1567 non-null   bool
#  32  day_21               1567 non-null   bool
#  33  day_22               1567 non-null   bool
#  34  day_23               1567 non-null   bool
#  35  day_24               1567 non-null   bool
#  36  day_25               1567 non-null   bool
#  37  day_26               1567 non-null   bool
#  38  day_27               1567 non-null   bool
#  39  day_28               1567 non-null   bool
#  40  day_29               1567 non-null   bool
#  41  day_30               1567 non-null   bool
#  42  day_31               1567 non-null   bool
#  43  shift_B              1567 non-null   bool
#  44  crew_E2              1567 non-null   bool
#  45  crew_E3              1567 non-null   bool
#  46  crew_E4              1567 non-null   bool
#  47  total                1567 non-null   float64
#  48  efectivo             1567 non-null   float64
#  49  mantencion           1567 non-null   float64
#  50  mecanica             1567 non-null   float64
#  51  electrica            1567 non-null   float64
#  52  mant_excl            1567 non-null   float64
#  53  mec_excl             1567 non-null   float64
#  54  elec_excl            1567 non-null   float64
#  55  som_excl             1567 non-null   float64
#  56  demora               1567 non-null   float64
#  57  r_prog               1567 non-null   float64
#  58  r_noprg              1567 non-null   float64
#  59  waiting              1567 non-null   int64
#  60  queued               1567 non-null   int64
#  61  material_tonnage     1567 non-null   float64
#  62  payload              1567 non-null   float64
#  63  distance             1567 non-null   int64
#  64  distance_down        1567 non-null   int64
#  65  distance_down_level  1567 non-null   int64
#  66  distance_up          1567 non-null   int64
#  67  distance_up_level    1567 non-null   int64
#  68  expected_time        1567 non-null   int64
#  69  lift_down            1567 non-null   int64
#  70  lift_down_level      1567 non-null   int64
#  71  lift_up              1567 non-null   int64
#  72  lift_up_level        1567 non-null   int64
#  73  travel_time          1567 non-null   int64
#  74  CAT 797-F            1567 non-null   float64
#  75  CAT 798-AC           1567 non-null   float64
#  76  KOM-CHQ              1567 non-null   float64
#  77  KOM.960E5            1567 non-null   float64
#  78  Kom.930E-4           1567 non-null   float64
#  79  Kom.930E-4SE         1567 non-null   float64
#  80  Kom.930EN            1567 non-null   float64
#  81  Kom.930ER            1567 non-null   float64
#  82  Kom.930ER-MT         1567 non-null   float64
#  83  Kom.980E5            1567 non-null   float64
#  84  Komatsu AHS          1567 non-null   float64
# dtypes: bool(47), float64(25), int64(13)
# memory usage: 537.3 KB

# %% [markdown]
# ## **_2 Preparación del DataFrame_**

# %%
# transformamos las variables bool a categorical y le asignamos 0 o 1
for col in df.columns:
  if df[col].dtype == 'bool':
     df[col] = df[col].astype('category').cat.codes
     df[col] = df[col].astype('category') # para que quede como category y no como int8

# %%
print('Nombre Columnas: ',df.columns)
print('Cantidad Columnas: ',len(df.columns))
# Out:
# Nombre Columnas:  Index(['year_2023', 'year_2024', 'month_2', 'month_3', 'month_4', 'month_5',
#        'month_6', 'month_7', 'month_8', 'month_9', 'month_10', 'month_11',
#        'month_12', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'day_7',
#        'day_8', 'day_9', 'day_10', 'day_11', 'day_12', 'day_13', 'day_14',
#        'day_15', 'day_16', 'day_17', 'day_18', 'day_19', 'day_20', 'day_21',
#        'day_22', 'day_23', 'day_24', 'day_25', 'day_26', 'day_27', 'day_28',
#        'day_29', 'day_30', 'day_31', 'shift_B', 'crew_E2', 'crew_E3',
#        'crew_E4', 'total', 'efectivo', 'mantencion', 'mecanica', 'electrica',
#        'mant_excl', 'mec_excl', 'elec_excl', 'som_excl', 'demora', 'r_prog',
#        'r_noprg', 'waiting', 'queued', 'material_tonnage', 'payload',
#        'distance', 'distance_down', 'distance_down_level', 'distance_up',
#        'distance_up_level', 'expected_time', 'lift_down', 'lift_down_level',
#        'lift_up', 'lift_up_level', 'travel_time', 'CAT 797-F', 'CAT 798-AC',
#        'KOM-CHQ', 'KOM.960E5', 'Kom.930E-4', 'Kom.930E-4SE', 'Kom.930EN',
#        'Kom.930ER', 'Kom.930ER-MT', 'Kom.980E5', 'Komatsu AHS'],
#       dtype='object')
# Cantidad Columnas:  85

# %%
# cálculamos la desviaicón estándar y la media de payload
std_y = df['payload'].std()
mean_y = df['payload'].mean()

print('Desviación Estándar:',std_y)
print('Media:',mean_y)
# Out:
# Desviación Estándar: 19936.05577427206
# Media: 142357.4639507874

# %%
# estandarizamos las variables numéricas
col_num = df.drop('payload', axis=1).select_dtypes(include=['float64','int64']).columns

scaler = StandardScaler()
df[col_num] = scaler.fit_transform(df[col_num])

# %% [markdown]
# ## **_3 XGBoost_**

# %%
# definimos el tamaño del set de test
test_size = 0.40

# %%
# separamos los datos en X e y
X = df.drop('payload', axis=1)
y = df['payload']

# dividimos los datos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
# Crear el modelo XGBoost
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', 
                             enable_categorical=True,
                             random_state=42)

# %%
# Entrenar el modelo
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
predictions_train = xgb_model.predict(X_train)

# %%
# resultados de R2, RMSE y MSE
R2_RMSE(y_train, predictions_train)
# Out:
# R2: 0.9999453451616311
# RMSE: 148.44640361225305
# MSE: 22036.334745411936
# (None, None, None)

# %%
# Realizar predicciones con el modelo entrenado
predictions_test = xgb_model.predict(X_test)

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test, predictions_test)
# Out:
# R2: 0.7543477521199697
# RMSE: 9764.770308007728
# MSE: 95350739.16814935
# (None, None, None)

# %% [markdown]
# ## _4 Optimización del Modelo_

# %% [markdown]
# ### _4.1 Selección de Variables (LassoCV)_

# %%
# buscamos alpha optimo con LassoCV
alpha_values = np.linspace(0.01, 300, 30000)

# Crea un objeto LassoCV
lasso_cv = LassoCV(alphas=alpha_values, cv=5)

# Ajusta el modelo a los datos de entrenamiento
lasso_cv.fit(X_train, y_train)

# Valor óptimo de alpha
best_alpha = lasso_cv.alpha_

# Evalúa el modelo en el conjunto de prueba
score = lasso_cv.score(X_test, y_test)

print(f"Mejor valor de alpha: {best_alpha}")
print(f"Puntuación en el conjunto de prueba: {score}")
# Out:
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29762946.52053833, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29809965.726623535, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29877489.38572693, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29961524.079162598, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30058920.060699463, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30167189.154579163, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30284365.303115845, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30408895.02622223, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30539551.720848083, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30675366.685791016, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30815576.67262268, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30959580.343559265, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31106905.49105835, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31257181.876586914, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31410120.51194763, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31565497.142684937, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31723138.322792053, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31882911.706062317, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32044717.28996277, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32208480.91986084, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32374149.17076111, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32541684.731437683, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32711064.058540344, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32882273.739356995, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33055309.092689514, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33230172.071136475, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33406870.523361206, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33585416.637924194, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33765826.301651, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33948118.58594513, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34132315.13169098, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32242216.842933655, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41052023.57305145, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48853310.19277954, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55595818.08870697, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61354151.33407593, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66242936.691459656, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70388961.51286316, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73956698.13777924, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76994032.6642685, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79604558.8623352, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81869299.02282715, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83855973.212677, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85620556.35957336, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87208937.32224274, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88658516.6807251, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89999647.54833984, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91256891.79917908, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92450087.25383759, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93595238.84187317, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94705256.69662476, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95790556.3387146, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96859554.10514832, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97919060.05952454, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98974605.4751358, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100030692.5995636, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101091012.7399826, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102158604.03968811, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103235990.20881653, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104325286.6944046, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105428284.37597656, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106546520.3911972, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107681331.71793365, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108833899.51200867, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110005284.77952576, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111196455.72421265, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112408311.09137726, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113641698.41209412, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114897428.0260315, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116176286.31691742, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117479042.7904129, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118806464.08377075, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120159310.65041351, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121538353.41352844, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122944367.7681427, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124378146.57636261, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125840495.19511414, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127332243.27216339, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 128854237.95890045, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130407355.37625885, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131992492.88559723, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 133610582.14370728, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135262581.67419434, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136949483.2983017, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138672315.0576706, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140432139.4352188, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142230057.11855316, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143774160.56537628, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134071836.5710144, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127189766.79447937, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120459637.5508194, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127200147.54537964, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134310507.50325775, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140528930.20870972, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146018472.13633728, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150921330.1251526, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155357171.47997284, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159425568.28099823, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163208743.861763, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166774257.42077637, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170177452.8480301, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173463607.41262817, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176669769.0059204, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179826296.50174713, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182958142.13313293, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 186085908.9943161, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 189226709.10971832, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192394869.81724548, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195602504.70723724, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 198859974.43746185, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202176264.12077332, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205559284.11294556, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209016117.9074936, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212553218.72866058, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 216176575.1587677, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 219891839.86852264, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 223704439.15685272, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 227619661.4430313, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231642734.84576416, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235778882.81937408, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 240033385.2565155, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244411617.99516296, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 248919095.38684845, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253561505.97129822, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 258344745.72724152, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 263274949.68707275, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 268358517.49752808, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 273602142.54306793, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 279012850.62184143, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 284598008.1702728, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 290365373.0886612, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 296323108.9187393, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 302479824.50787354, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308844603.77677155, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315427045.1440964, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 322237292.6168518, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 301013918.75466156, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187147835.34197998, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138545698.28194427, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118088197.9951706, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111115413.90164948, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154417328.28342438, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203081409.89170074, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247610535.612175, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287641694.3513794, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323418849.6996002, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 355433776.99922943, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 384258181.45053864, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 410459756.5654526, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 434563223.4761429, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 457035325.9677048, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 478282318.3759308, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 685712644.0378876, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 708878160.9335785, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 733157980.4050903, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 758648746.4319382, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 785452401.4702911, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 813677413.1300735, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 843440061.3143616, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 874865775.7966537, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 908090573.8069916, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 943262612.2961273, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 980543933.1204681, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1020112376.4071426, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1062163756.6127777, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1106914308.1353912, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1154884416.4051743, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1206536496.567299, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1261641401.292122, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1320494436.1147156, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1383482506.0223541, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1451035533.084961, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1523633608.1832275, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1601724441.9343262, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1715805679.145111, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1699151163.4961624, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1810005663.6968155, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1929652687.8445702, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2056965085.4765701, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2193440347.857029, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2340721294.310093, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2500629324.931076, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2675217172.274952, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2866831669.162922, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3078189939.398777, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3312473424.293461, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3573445675.2628136, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3865601989.6344337, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4194362025.440445, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4566320916.939468, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4989580700.248783, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5474193487.21925, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6032762225.967094, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6681266937.719269, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7440219086.198364, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8336302191.756454, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9404751174.020222, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10693229210.624723, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12265462450.476055, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14210592397.460707, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16660631637.540476, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19806318918.161423, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# Mejor valor de alpha: 56.089999999999996
# Puntuación en el conjunto de prueba: 0.8066467716870184

# %%
# Graficar MSE vs. Alpha
plt.figure(figsize=(10,6))
plt.plot(lasso_cv.alphas_, np.mean(lasso_cv.mse_path_, axis=1), '-o')
plt.xlabel('Alpha')
plt.ylabel('Mean MSE across CV folds')
plt.title('Path de Regularización')
plt.axvline(lasso_cv.alpha_, color='red', linestyle='--')

# Anotar el valor óptimo de alpha en el gráfico
plt.annotate(f'Optimal alpha: {lasso_cv.alpha_:.2f}, MSE: {np.min(np.mean(lasso_cv.mse_path_, axis=1)):.2f}',
             xy=(lasso_cv.alpha_, np.min(np.mean(lasso_cv.mse_path_, axis=1))),
             xycoords='data', xytext=(10,100), 
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1.5),
             fontsize=9)

plt.show()

# %%
# Aplicar Lasso para la selección de características
lasso = Lasso(alpha=lasso_cv.alpha_)  
lasso.fit(X_train, y_train)

# Seleccionar las características que tienen coeficientes no nulos
selected_features = X_train.columns[lasso.coef_ != 0]

print("Características seleccionadas:")
print(selected_features)
# Out:
# Características seleccionadas:
# Index(['year_2024', 'month_3', 'month_5', 'month_6', 'month_7', 'month_8',
#        'month_9', 'month_10', 'month_11', 'day_2', 'day_5', 'day_10', 'day_12',
#        'day_14', 'day_22', 'day_25', 'day_26', 'shift_B', 'crew_E2', 'crew_E3',
#        'crew_E4', 'total', 'efectivo', 'mecanica', 'electrica', 'mant_excl',
#        'mec_excl', 'elec_excl', 'som_excl', 'demora', 'r_noprg', 'waiting',
#        'queued', 'material_tonnage', 'distance_down', 'distance_down_level',
#        'distance_up', 'distance_up_level', 'expected_time', 'lift_down',
#        'lift_up', 'lift_up_level', 'travel_time', 'CAT 797-F', 'CAT 798-AC',
#        'KOM.960E5', 'Kom.930E-4', 'Kom.930EN', 'Kom.930ER', 'Kom.980E5',
#        'Komatsu AHS'],
#       dtype='object')

# %%
len(selected_features)
# Out:
# 51

# %% [markdown]
# > Volvemos ajustar el modelo con las variables seleccionadas

# %%
# separamos los datos en train y test
X_lasso= df[selected_features]
y_lasso = df['payload']

# dividimos los datos en train y test
X_train_lasso, X_test_lasso, y_train_lasso, y_test_lasso = train_test_split(X_lasso, y_lasso, test_size=test_size, random_state=42)

# %%
# Inicializar el regresor AdaBoost
xgb_model_lasso = xgb.XGBRegressor(objective='reg:squarederror', 
                                   enable_categorical=True,
                                   random_state=42)

# %%
# Entrenar el modelo AdaBoost
xgb_model_lasso.fit(X_train_lasso, y_train_lasso)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# #### 4.1.1 Predicciones en el conjunto de entrenamiento

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_train = xgb_model_lasso.predict(X_train_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_train_lasso, predictions_lasso_train)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 37244.34

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_train_lasso, predictions_lasso_train)
# Out:
# R2: 0.9999076260455894
# RMSE: 192.98792700273688
# MSE: 37244.3399688137
# (None, None, None)

# %% [markdown]
# #### 4.1.2 Predicciones en el conjunto de testeo

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_test = xgb_model_lasso.predict(X_test_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_test_lasso, predictions_lasso_test)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 91126626.43

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test_lasso, predictions_lasso_test)
# Out:
# R2: 0.7652303399023672
# RMSE: 9546.026735310708
# MSE: 91126626.43126681
# (None, None, None)

# %% [markdown]
# ### _4.2 Optimización de Hiperparámetros_

# %%
# Definir los hiperparámetros para la búsqueda
param_dist_xgb = {
    'n_estimators': randint(50, 500),
    'learning_rate': uniform(0.01, 0.6),
    'subsample': uniform(0.3, 0.7),
    'max_depth': randint(1, 20),
    'colsample_bytree': uniform(0.5, 0.5),
    'gamma': uniform(0, 0.5),
    'reg_alpha': uniform(0, 1),  # L1 regularization term
    'reg_lambda': uniform(1, 4)  # L2 regularization term
}

# Crear el modelo XGBoost
xgb_model_hip= xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42)

# Crear la búsqueda de hiperparámetros
random_search_xgb = RandomizedSearchCV(
    estimator=xgb_model_hip,
    param_distributions=param_dist_xgb,
    n_iter=100,
    cv=5,
    scoring='r2',
    random_state=42,
    n_jobs=-1
)

# Ajustar el modelo
random_search_xgb.fit(X_train_lasso, y_train_lasso)

# Obtener los mejores hiperparámetros
best_params_xgb = random_search_xgb.best_params_
print("Best parameters for XGBoost: ", best_params_xgb)
# Out:
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best parameters for XGBoost:  {'colsample_bytree': 0.5316874852363839, 'gamma': 0.4949801161949726, 'learning_rate': 0.20341230698483379, 'max_depth': 2, 'n_estimators': 133, 'reg_alpha': 0.25464065476376385, 'reg_lambda': 3.726010888895717, 'subsample': 0.8321595019227805}

# %%
# Crear el modelo XGBoost con los mejores hiperparámetros
xgb_model_best = xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42,
                             **best_params_xgb)

# %%
# Entrenar el modelo con los mejores hiperparámetros
xgb_model_best.fit(X_train_lasso, y_train_lasso,
                   eval_set=[(X_test_lasso, y_test_lasso)],
                   early_stopping_rounds=10,
                   verbose=False)
# Out:
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5316874852363839, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=0.4949801161949726,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.20341230698483379,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=133, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
train_predictions = xgb_model_best.predict(X_train_lasso)

# Realizar predicciones en el conjunto de prueba
test_predictions = xgb_model_best.predict(X_test_lasso)

# %%
# Evaluar el modelo en el conjunto de entrenamiento
train_r2 = r2_score(y_train_lasso, train_predictions)
train_mse = mean_squared_error(y_train_lasso, train_predictions)
train_rmse = np.sqrt(train_mse)

print(f"R2 en el conjunto de entrenamiento: {train_r2:.3f}")
print(f"MSE en el conjunto de entrenamiento: {train_mse:.2f}")
print(f"RMSE en el conjunto de entrenamiento: {train_rmse:.2f}")
# Out:
# R2 en el conjunto de entrenamiento: 0.867
# MSE en el conjunto de entrenamiento: 53544258.25
# RMSE en el conjunto de entrenamiento: 7317.39

# %%
# Evaluar el modelo en el conjunto de prueba
test_r2 = r2_score(y_test_lasso, test_predictions)
test_mse = mean_squared_error(y_test_lasso, test_predictions)
test_rmse = np.sqrt(test_mse)

print(f"R2 en el conjunto de prueba: {test_r2:.3f}")
print(f"MSE en el conjunto de prueba: {test_mse:.2f}")
print(f"RMSE en el conjunto de prueba: {test_rmse:.2f}")
# Out:
# R2 en el conjunto de prueba: 0.793
# MSE en el conjunto de prueba: 80415444.91
# RMSE en el conjunto de prueba: 8967.47
