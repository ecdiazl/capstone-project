# %% [markdown]
# ## **Capstone MDS - XGBoost**

# %% [markdown]
# #### **_Integrantes:_**
#
# 1. Evans Díaz
# 1. Felipe Ojeda
# 1. Javier Cofre
# 1. Luis Reinoso

# %%
# importar librerías
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import statsmodels.api as sm
import shap
import xgboost as xgb

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import randint, uniform
from matplotlib.ticker import EngFormatter

# %%
# función cálculo R2, RMSE y MSE
def R2_RMSE(y_true, y_pred):
  # cálculo de R2 y RMSE
  r2 = r2_score(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mse)
  
  return print('R2:',r2), print('RMSE:',rmse), print('MSE:', mse)

# %% [markdown]
# ## **_1. Lectura (carga) de los Datos_**

# %%
# importamos archivo
df = pd.read_csv('../Data/df_final_pay_sin_mt.csv')

# %%
# miramos el dataframe
df.head()
# Out:
#    year_2023  year_2024  month_2  month_3  month_4  month_5  month_6  month_7  \
# 0      False      False    False    False    False    False    False    False
# 1      False      False    False    False    False    False    False    False
# 2      False      False    False    False    False    False    False    False
# 3      False      False    False    False    False    False    False    False
# 4      False      False    False    False    False    False    False    False
#
#    month_8  month_9  ...  CAT 798-AC  KOM-CHQ  KOM.960E5  Kom.930E-4  \
# 0    False    False  ...         0.0      0.0       24.0        96.0
# 1    False    False  ...         0.0      0.0       24.0        96.0
# 2    False    False  ...         0.0      0.0       24.0        96.0
# 3    False    False  ...         0.0      0.0       24.0        95.0
# 4    False    False  ...         0.0      0.0       24.0        96.0
#
#    Kom.930E-4SE  Kom.930EN  Kom.930ER  Kom.930ER-MT  Kom.980E5  Komatsu AHS
# 0         395.0       96.0      240.0           0.0      132.0         24.0
# 1         396.0       96.0      240.0           0.0      132.0         24.0
# 2         394.0       96.0      240.0           0.0      132.0         24.0
# 3         396.0       96.0      240.0           0.0      132.0         24.0
# 4         395.0       96.0      240.0           0.0      132.0         24.0
#
# [5 rows x 84 columns]

# %%
# información general df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Data columns (total 84 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_2023            1567 non-null   bool
#  1   year_2024            1567 non-null   bool
#  2   month_2              1567 non-null   bool
#  3   month_3              1567 non-null   bool
#  4   month_4              1567 non-null   bool
#  5   month_5              1567 non-null   bool
#  6   month_6              1567 non-null   bool
#  7   month_7              1567 non-null   bool
#  8   month_8              1567 non-null   bool
#  9   month_9              1567 non-null   bool
#  10  month_10             1567 non-null   bool
#  11  month_11             1567 non-null   bool
#  12  month_12             1567 non-null   bool
#  13  day_2                1567 non-null   bool
#  14  day_3                1567 non-null   bool
#  15  day_4                1567 non-null   bool
#  16  day_5                1567 non-null   bool
#  17  day_6                1567 non-null   bool
#  18  day_7                1567 non-null   bool
#  19  day_8                1567 non-null   bool
#  20  day_9                1567 non-null   bool
#  21  day_10               1567 non-null   bool
#  22  day_11               1567 non-null   bool
#  23  day_12               1567 non-null   bool
#  24  day_13               1567 non-null   bool
#  25  day_14               1567 non-null   bool
#  26  day_15               1567 non-null   bool
#  27  day_16               1567 non-null   bool
#  28  day_17               1567 non-null   bool
#  29  day_18               1567 non-null   bool
#  30  day_19               1567 non-null   bool
#  31  day_20               1567 non-null   bool
#  32  day_21               1567 non-null   bool
#  33  day_22               1567 non-null   bool
#  34  day_23               1567 non-null   bool
#  35  day_24               1567 non-null   bool
#  36  day_25               1567 non-null   bool
#  37  day_26               1567 non-null   bool
#  38  day_27               1567 non-null   bool
#  39  day_28               1567 non-null   bool
#  40  day_29               1567 non-null   bool
#  41  day_30               1567 non-null   bool
#  42  day_31               1567 non-null   bool
#  43  shift_B              1567 non-null   bool
#  44  crew_E2              1567 non-null   bool
#  45  crew_E3              1567 non-null   bool
#  46  crew_E4              1567 non-null   bool
#  47  total                1567 non-null   float64
#  48  efectivo             1567 non-null   float64
#  49  mantencion           1567 non-null   float64
#  50  mecanica             1567 non-null   float64
#  51  electrica            1567 non-null   float64
#  52  mant_excl            1567 non-null   float64
#  53  mec_excl             1567 non-null   float64
#  54  elec_excl            1567 non-null   float64
#  55  som_excl             1567 non-null   float64
#  56  demora               1567 non-null   float64
#  57  r_prog               1567 non-null   float64
#  58  r_noprg              1567 non-null   float64
#  59  waiting              1567 non-null   int64
#  60  queued               1567 non-null   int64
#  61  payload              1567 non-null   float64
#  62  distance             1567 non-null   int64
#  63  distance_down        1567 non-null   int64
#  64  distance_down_level  1567 non-null   int64
#  65  distance_up          1567 non-null   int64
#  66  distance_up_level    1567 non-null   int64
#  67  expected_time        1567 non-null   int64
#  68  lift_down            1567 non-null   int64
#  69  lift_down_level      1567 non-null   int64
#  70  lift_up              1567 non-null   int64
#  71  lift_up_level        1567 non-null   int64
#  72  travel_time          1567 non-null   int64
#  73  CAT 797-F            1567 non-null   float64
#  74  CAT 798-AC           1567 non-null   float64
#  75  KOM-CHQ              1567 non-null   float64
#  76  KOM.960E5            1567 non-null   float64
#  77  Kom.930E-4           1567 non-null   float64
#  78  Kom.930E-4SE         1567 non-null   float64
#  79  Kom.930EN            1567 non-null   float64
#  80  Kom.930ER            1567 non-null   float64
#  81  Kom.930ER-MT         1567 non-null   float64
#  82  Kom.980E5            1567 non-null   float64
#  83  Komatsu AHS          1567 non-null   float64
# dtypes: bool(47), float64(24), int64(13)
# memory usage: 525.0 KB

# %% [markdown]
# ## **_2 Preparación del DataFrame_**

# %%
# transformamos las variables bool a categorical y le asignamos 0 o 1
for col in df.columns:
  if df[col].dtype == 'bool':
     df[col] = df[col].astype('category').cat.codes
     df[col] = df[col].astype('category') # para que quede como category y no como int8

# %%
print('Nombre Columnas: ',df.columns)
print('Cantidad Columnas: ',len(df.columns))
# Out:
# Nombre Columnas:  Index(['year_2023', 'year_2024', 'month_2', 'month_3', 'month_4', 'month_5',
#        'month_6', 'month_7', 'month_8', 'month_9', 'month_10', 'month_11',
#        'month_12', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'day_7',
#        'day_8', 'day_9', 'day_10', 'day_11', 'day_12', 'day_13', 'day_14',
#        'day_15', 'day_16', 'day_17', 'day_18', 'day_19', 'day_20', 'day_21',
#        'day_22', 'day_23', 'day_24', 'day_25', 'day_26', 'day_27', 'day_28',
#        'day_29', 'day_30', 'day_31', 'shift_B', 'crew_E2', 'crew_E3',
#        'crew_E4', 'total', 'efectivo', 'mantencion', 'mecanica', 'electrica',
#        'mant_excl', 'mec_excl', 'elec_excl', 'som_excl', 'demora', 'r_prog',
#        'r_noprg', 'waiting', 'queued', 'payload', 'distance', 'distance_down',
#        'distance_down_level', 'distance_up', 'distance_up_level',
#        'expected_time', 'lift_down', 'lift_down_level', 'lift_up',
#        'lift_up_level', 'travel_time', 'CAT 797-F', 'CAT 798-AC', 'KOM-CHQ',
#        'KOM.960E5', 'Kom.930E-4', 'Kom.930E-4SE', 'Kom.930EN', 'Kom.930ER',
#        'Kom.930ER-MT', 'Kom.980E5', 'Komatsu AHS'],
#       dtype='object')
# Cantidad Columnas:  84

# %%
# cálculamos la desviaicón estándar y la media de payload
std_y = df['payload'].std()
mean_y = df['payload'].mean()

print('Desviación Estándar:',std_y)
print('Media:',mean_y)
# Out:
# Desviación Estándar: 19936.05577427206
# Media: 142357.4639507874

# %%
# estandarizamos las variables numéricas
col_num = df.drop('payload', axis=1).select_dtypes(include=['float64','int64']).columns

scaler = StandardScaler()
df[col_num] = scaler.fit_transform(df[col_num])

# %% [markdown]
# ## **_3 XGBoost_**

# %%
# definimos el tamaño del set de test
test_size = 0.40

# %%
# separamos los datos en X e y
X = df.drop('payload', axis=1)
y = df['payload']

# dividimos los datos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
# Crear el modelo XGBoost
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', 
                             enable_categorical=True,
                             random_state=42)

# %%
# Entrenar el modelo
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
predictions_train = xgb_model.predict(X_train)

# %%
# resultados de R2, RMSE y MSE
R2_RMSE(y_train, predictions_train)
# Out:
# R2: 0.9999310426826591
# RMSE: 166.74220955661028
# MSE: 27802.964447820534
# (None, None, None)

# %%
# Realizar predicciones con el modelo entrenado
predictions_test = xgb_model.predict(X_test)

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test, predictions_test)
# Out:
# R2: 0.6520144148527937
# RMSE: 11622.037913799262
# MSE: 135071765.26978752
# (None, None, None)

# %% [markdown]
# ## _4 Optimización del Modelo_

# %% [markdown]
# ### _4.1 Selección de Variables (LassoCV)_

# %%
# buscamos alpha optimo con LassoCV
alpha_values = np.linspace(0.01, 300, 30000)

# Crea un objeto LassoCV
lasso_cv = LassoCV(alphas=alpha_values, cv=5)

# Ajusta el modelo a los datos de entrenamiento
lasso_cv.fit(X_train, y_train)

# Valor óptimo de alpha
best_alpha = lasso_cv.alpha_

# Evalúa el modelo en el conjunto de prueba
score = lasso_cv.score(X_test, y_test)

print(f"Mejor valor de alpha: {best_alpha}")
print(f"Puntuación en el conjunto de prueba: {score}")
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35274870.450927734, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43757697.08035278, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51165916.42274475, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57504167.061691284, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62866933.11714172, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67377680.92359924, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71164223.37019348, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74346468.58132935, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77031073.17166138, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79309872.68203735, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81260266.68759155, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82946535.628479, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84421508.56730652, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85728274.04180908, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86901780.97817993, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87970259.23812866, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88956442.72470093, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89878600.15052795, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90751388.56747437, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91586556.95698547, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92393520.25357056, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93179820.77384949, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93951507.03378296, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94713429.10523987, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95469488.64067078, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96222822.55825806, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96975969.6025238, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97862259.90657043, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98641283.03153992, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99417316.17144775, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100197210.76223755, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100982366.75254822, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101773929.3361969, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102572848.03025818, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103379923.88345337, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104195837.81941223, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105021176.55802917, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105856454.46690369, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106702127.44587708, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107558607.15995789, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108426271.97346497, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109305472.54077148, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110196541.96681213, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111099797.85484314, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112015548.96688843, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112944096.64674377, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113885738.29064941, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114840772.06608582, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115809492.7054596, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116792201.12359619, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117789197.61608887, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118800788.46984863, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119827284.17727661, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120869001.53903198, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91512754.05358887, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60119170.90649414, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47085652.46437073, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41406062.26138306, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38907639.57395935, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37867220.218566895, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37518816.03315735, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37506004.73069763, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37658704.58958435, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37894702.96321106, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38174025.47453308, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38477200.72766113, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38794760.08830261, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39122127.948150635, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45440375.076660156, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62924912.51199341, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79524914.83172607, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94197004.81126404, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106908393.04870605, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117801749.41558838, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127091490.75527954, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135016156.5952301, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141794485.0580597, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147621560.06851196, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152674863.11216736, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157102820.2694702, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161029469.03907776, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164557329.74934387, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167770482.49874878, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170737499.1520691, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173514090.35379028, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176145401.5797577, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178667961.38594055, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181111313.06965637, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 183499352.62483215, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185851437.36213684, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188183272.34983826, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 190507647.39274597, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192835016.3518219, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195173967.52157593, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197531614.10914612, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199913887.6797943, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202325789.25830078, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204771583.99024963, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 207254958.42848206, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209779146.21159363, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212347030.29101562, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 214961224.5711975, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217624135.56430054, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 220338021.6301422, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 223105030.25099182, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225927232.51068115, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 228806653.4567566, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231745296.37583923, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234745157.31411743, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 237808242.7086792, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 240936585.87417603, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244132253.22409058, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247397355.56069946, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250734059.15878296, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254144590.50964355, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265749900.62911987, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184445269.9346161, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132960039.17198181, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155394312.6211853, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180718812.13627625, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202805186.38352966, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 221953302.17114258, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 238553201.49639893, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253001634.386261, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265668053.2614746, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276880359.3468933, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 286921216.4522095, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 296029748.66316223, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304405728.36361694, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312214653.8604126, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319592896.54992676, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326652455.6885681, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333485201.8097687, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340166502.42974854, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 346758308.94299316, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 353311712.38879395, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 359869060.799881, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 366465695.89056396, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 373131372.5033264, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379891402.02975464, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386767601.1530304, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 393749757.87335205, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1236181107.2248077, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1279812568.379593, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1325850830.8395462, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1374476133.550293, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1425885947.7999344, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1480296987.4740143, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1537947485.7682953, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1599099832.161522, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1664043531.1399689, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1733098651.7332153, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1806619781.8241043, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1885000578.9487, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1968802998.7248306, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2058503489.0100327, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2154521229.234398, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2257458458.467407, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2368008079.287567, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2486949565.946747, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2615162719.6012573, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2753643957.9066467, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2903525737.1737747, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3066099804.1926804, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3242845069.8693695, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3435461380.9924927, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3645910523.2576065, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3876466339.615959, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4129776377.426941, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4408938251.923485, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4717594686.712334, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5060052984.7612, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441436033.646088, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5867874967.236542, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6346756995.156654, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6887047507.449448, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7499712514.424095, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8198279469.401398, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8999590143.404617, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9924825042.62918, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11000917295.180382, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12262534481.875648, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13754905528.338467, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15537930677.751389, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17692285785.046997, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20328709379.89658, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23602519801.670948, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27737021186.939735, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33062609666.403248, tolerance: 30679684.74939173
#   model = cd_fast.enet_coordinate_descent_gram(
# Mejor valor de alpha: 64.59
# Puntuación en el conjunto de prueba: 0.7100250304345364

# %%
# Graficar MSE vs. Alpha
plt.figure(figsize=(10,6))
plt.plot(lasso_cv.alphas_, np.mean(lasso_cv.mse_path_, axis=1), '-o')
plt.xlabel('Alpha')
plt.ylabel('Mean MSE across CV folds')
plt.title('Path de Regularización')
plt.axvline(lasso_cv.alpha_, color='red', linestyle='--')

# Anotar el valor óptimo de alpha en el gráfico
plt.annotate(f'Optimal alpha: {lasso_cv.alpha_:.2f}, MSE: {np.min(np.mean(lasso_cv.mse_path_, axis=1)):.2f}',
             xy=(lasso_cv.alpha_, np.min(np.mean(lasso_cv.mse_path_, axis=1))),
             xycoords='data', xytext=(10,100), 
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1.5),
             fontsize=9)

plt.show()

# %%
# Aplicar Lasso para la selección de características
lasso = Lasso(alpha=lasso_cv.alpha_)  
lasso.fit(X_train, y_train)

# Seleccionar las características que tienen coeficientes no nulos
selected_features = X_train.columns[lasso.coef_ != 0]

print("Características seleccionadas:")
print(selected_features)
# Out:
# Características seleccionadas:
# Index(['year_2024', 'month_3', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_11', 'day_2', 'day_3', 'day_4', 'day_5', 'day_17', 'day_19',
#        'day_22', 'day_23', 'day_26', 'day_27', 'day_28', 'day_30', 'shift_B',
#        'crew_E2', 'crew_E4', 'efectivo', 'mecanica', 'electrica', 'mant_excl',
#        'mec_excl', 'elec_excl', 'demora', 'r_noprg', 'waiting', 'queued',
#        'distance_down_level', 'distance_up', 'distance_up_level',
#        'expected_time', 'lift_down', 'lift_down_level', 'lift_up_level',
#        'travel_time', 'CAT 797-F', 'CAT 798-AC', 'KOM-CHQ', 'KOM.960E5',
#        'Kom.930E-4', 'Kom.930EN', 'Kom.930ER', 'Kom.930ER-MT', 'Kom.980E5',
#        'Komatsu AHS'],
#       dtype='object')

# %%
len(selected_features)
# Out:
# 50

# %% [markdown]
# > Volvemos ajustar el modelo con las variables seleccionadas

# %%
# separamos los datos en train y test
X_lasso= df[selected_features]
y_lasso = df['payload']

# dividimos los datos en train y test
X_train_lasso, X_test_lasso, y_train_lasso, y_test_lasso = train_test_split(X_lasso, y_lasso, test_size=test_size, random_state=42)

# %%
# Inicializar el regresor AdaBoost
xgb_model_lasso = xgb.XGBRegressor(objective='reg:squarederror', 
                                   enable_categorical=True,
                                   random_state=42)

# %%
# Entrenar el modelo AdaBoost
xgb_model_lasso.fit(X_train_lasso, y_train_lasso)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# #### 4.1.1 Predicciones en el conjunto de entrenamiento

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_train = xgb_model_lasso.predict(X_train_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_train_lasso, predictions_lasso_train)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 75148.59

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_train_lasso, predictions_lasso_train)
# Out:
# R2: 0.9998136153823491
# RMSE: 274.13242435334337
# MSE: 75148.58608184152
# (None, None, None)

# %% [markdown]
# #### 4.1.2 Predicciones en el conjunto de testeo

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_test = xgb_model_lasso.predict(X_test_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_test_lasso, predictions_lasso_test)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 136901761.23

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test_lasso, predictions_lasso_test)
# Out:
# R2: 0.647299793600212
# RMSE: 11700.502605887597
# MSE: 136901761.23038247
# (None, None, None)

# %% [markdown]
# ### _4.2 Optimización de Hiperparámetros_

# %%
# Definir los hiperparámetros para la búsqueda
param_dist_xgb = {
    'n_estimators': randint(50, 1000),
    'learning_rate': uniform(0.01, 0.6),
    'subsample': uniform(0.3, 0.7),
    'max_depth': randint(1, 20),
    'colsample_bytree': uniform(0.5, 0.5),
    'gamma': uniform(0, 0.5),
    'reg_alpha': uniform(0, 1),  # L1 regularization term
    'reg_lambda': uniform(1, 4)  # L2 regularization term
}

# Crear el modelo XGBoost
xgb_model_hip= xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42)

# Crear la búsqueda de hiperparámetros
random_search_xgb = RandomizedSearchCV(
    estimator=xgb_model_hip,
    param_distributions=param_dist_xgb,
    n_iter=2000,
    cv=5,
    scoring='r2',
    random_state=42,
    n_jobs=-1
)

# Ajustar el modelo
random_search_xgb.fit(X_train_lasso, y_train_lasso)

# Obtener los mejores hiperparámetros
best_params_xgb = random_search_xgb.best_params_
print("Best parameters for XGBoost: ", best_params_xgb)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best parameters for XGBoost:  {'colsample_bytree': 0.8027646374456361, 'gamma': 0.2423890300452235, 'learning_rate': 0.07346734413644018, 'max_depth': 4, 'n_estimators': 134, 'reg_alpha': 0.8903144562136512, 'reg_lambda': 3.1999536634638117, 'subsample': 0.5893916026217361}

# %%
# Crear el modelo XGBoost con los mejores hiperparámetros
xgb_model_best = xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42,
                             **best_params_xgb)

# %%
# Entrenar el modelo con los mejores hiperparámetros
xgb_model_best.fit(X_train_lasso, y_train_lasso,
                   eval_set=[(X_test_lasso, y_test_lasso)],
                   #early_stopping_rounds=10,
                   verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8027646374456361, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=0.2423890300452235,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07346734413644018,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=134, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
train_predictions = xgb_model_best.predict(X_train_lasso)

# Realizar predicciones en el conjunto de prueba
test_predictions = xgb_model_best.predict(X_test_lasso)

# %%
# Evaluar el modelo en el conjunto de entrenamiento
train_r2 = r2_score(y_train_lasso, train_predictions)
train_mse = mean_squared_error(y_train_lasso, train_predictions)
train_rmse = np.sqrt(train_mse)

print(f"R2 en el conjunto de entrenamiento: {train_r2:.3f}")
print(f"MSE en el conjunto de entrenamiento: {train_mse:.2f}")
print(f"RMSE en el conjunto de entrenamiento: {train_rmse:.2f}")
# Out:
# R2 en el conjunto de entrenamiento: 0.896
# MSE en el conjunto de entrenamiento: 41991921.91
# RMSE en el conjunto de entrenamiento: 6480.12

# %%
# Evaluar el modelo en el conjunto de prueba
test_r2 = r2_score(y_test_lasso, test_predictions)
test_mse = mean_squared_error(y_test_lasso, test_predictions)
test_rmse = np.sqrt(test_mse)

print(f"R2 en el conjunto de prueba: {test_r2:.3f}")
print(f"MSE en el conjunto de prueba: {test_mse:.2f}")
print(f"RMSE en el conjunto de prueba: {test_rmse:.2f}")
# Out:
# R2 en el conjunto de prueba: 0.700
# MSE en el conjunto de prueba: 116411157.28
# RMSE en el conjunto de prueba: 10789.40

# %% [markdown]
# ### _4.3 Graficamos los hiperparámetros_

# %%
# Convertir cv_results_ a un DataFrame de pandas
results_df = pd.DataFrame(random_search_xgb.cv_results_)

# Mostrar el DataFrame
results_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.339366      0.008155         0.011837        0.003907
# 1       0.131281      0.010661         0.010811        0.004094
# 2       1.529520      0.030858         0.015630        0.004257
# 3       1.705756      0.079651         0.021379        0.004553
# 4       2.045849      0.076879         0.012719        0.000984
#
#    param_colsample_bytree  param_gamma  param_learning_rate  param_max_depth  \
# 0                0.687270     0.475357             0.449196                7
# 1                0.800558     0.354036             0.022351                2
# 2                0.591702     0.152121             0.324854               12
# 3                0.646072     0.183181             0.283642               15
# 4                0.929970     0.340154             0.280300               18
#
#    param_n_estimators  param_reg_alpha  ...  param_subsample  \
# 0                 171         0.155995  ...         0.906323
# 1                 393         0.832443  ...         0.427277
# 2                 906         0.291229  ...         0.397646
# 3                 612         0.382462  ...         0.626734
# 4                 437         0.942202  ...         0.569792
#
#                                               params split0_test_score  \
# 0  {'colsample_bytree': 0.6872700594236812, 'gamm...          0.652173
# 1  {'colsample_bytree': 0.8005575058716043, 'gamm...          0.703786
# 2  {'colsample_bytree': 0.5917022549267169, 'gamm...          0.603068
# 3  {'colsample_bytree': 0.6460723242676091, 'gamm...          0.654218
# 4  {'colsample_bytree': 0.9299702033681603, 'gamm...          0.609752
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.590954           0.458542           0.675319           0.630627
# 1           0.630338           0.530139           0.670016           0.651743
# 2           0.487912           0.461852           0.553889           0.546690
# 3           0.604459           0.511251           0.623466           0.625573
# 4           0.598135           0.476572           0.607753           0.611816
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.601523        0.076699              678
# 1         0.637204        0.058705              147
# 2         0.530682        0.050202             1484
# 3         0.603794        0.048926              645
# 4         0.580805        0.052327              984
#
# [5 rows x 21 columns]

# %%
results_df.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_colsample_bytree', 'param_gamma', 'param_learning_rate',
#        'param_max_depth', 'param_n_estimators', 'param_reg_alpha',
#        'param_reg_lambda', 'param_subsample', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'mean_test_score', 'std_test_score',
#        'rank_test_score'],
#       dtype='object')

# %% [markdown]
# #### 4.3.1 Gráfica de learning_rate vs. n_estimators

# %%
# graficar la relación entre el RMSE y los valores de los hiperparámetros
plt.figure(figsize=(10,6))
sns.scatterplot(data=results_df, x='param_learning_rate', y='mean_test_score', hue='param_n_estimators', palette='viridis')

# mejoramos la visualización
#plt.title('Mean Test Score vs. Learning Rate')
plt.xlabel('Learning Rate')
plt.ylabel('Mean Test Score')
plt.legend(title='Número de Estimadores')
sns.despine()

# anotamos el mejor valor de learning rate
plt.annotate(f'Best Learning Rate: {best_params_xgb["learning_rate"]:.2f}',
             xy=(best_params_xgb['learning_rate'], random_search_xgb.best_score_),
             xycoords='data', xytext=(10,10), 
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1.5),
             fontsize=9)

# guardamos la imagen con alta resolución
plt.savefig('../Graficos/xgboost_lr.svg', dpi=600)

plt.show()

# %% [markdown]
# ### _4.4 Importancia de las Variables_

# %% [markdown]
# #### 4.4.1 Método Feature Importance

# %%
# Mostrar importancia de las características
df_importance = pd.DataFrame({'Feature':X_train_lasso.columns, 
                              'Importance':xgb_model_best.feature_importances_})

# Ordenar las características por importancia
df_importance = df_importance.sort_values('Importance', ascending=False)
df_importance
# Out:
#                 Feature  Importance
# 49          Komatsu AHS    0.193967
# 34    distance_up_level    0.186860
# 45            Kom.930EN    0.055235
# 30              waiting    0.041848
# 40            CAT 797-F    0.038366
# 31               queued    0.024818
# 22             efectivo    0.024511
# 21              crew_E4    0.024107
# 0             year_2024    0.021416
# 26             mec_excl    0.020109
# 1               month_3    0.019123
# 20              crew_E2    0.018477
# 35        expected_time    0.018248
# 23             mecanica    0.017776
# 32  distance_down_level    0.017697
# 3               month_7    0.015339
# 42              KOM-CHQ    0.014985
# 29              r_noprg    0.014428
# 33          distance_up    0.014087
# 37      lift_down_level    0.013649
# 36            lift_down    0.013261
# 28               demora    0.013250
# 38        lift_up_level    0.012742
# 5               month_9    0.012441
# 39          travel_time    0.011931
# 41           CAT 798-AC    0.011462
# 25            mant_excl    0.011414
# 13               day_22    0.010468
# 27            elec_excl    0.009403
# 7                 day_2    0.009150
# 18               day_30    0.008140
# 24            electrica    0.007653
# 15               day_26    0.007225
# 2               month_6    0.007184
# 10                day_5    0.006959
# 4               month_8    0.006846
# 11               day_17    0.006795
# 19              shift_B    0.006157
# 44           Kom.930E-4    0.005866
# 12               day_19    0.005349
# 9                 day_4    0.004402
# 8                 day_3    0.004070
# 17               day_28    0.003840
# 6              month_11    0.003837
# 48            Kom.980E5    0.003826
# 16               day_27    0.001147
# 14               day_23    0.000135
# 43            KOM.960E5    0.000000
# 46            Kom.930ER    0.000000
# 47         Kom.930ER-MT    0.000000

# %% [markdown]
# #### 4.4.2 Método Shapley

# %%
# Crear el objeto explainer SHAP con el modelo entrenado
explainer = shap.TreeExplainer(xgb_model_best)

# Calcular los valores SHAP para el conjunto de prueba
shap_values = explainer.shap_values(X_test_lasso)

# Visualizar la importancia de las características
shap.summary_plot(shap_values, 
                  X_test_lasso, 
                  feature_names=X_test_lasso.columns, 
                  plot_type='bar', 
                  color='silver',
                  max_display=10,
                  plot_size=(10, 10))

# Mostrar la gráfica
plt.show()
