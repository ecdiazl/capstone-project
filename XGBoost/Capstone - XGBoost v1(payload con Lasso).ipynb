# %% [markdown]
# ## **Capstone MDS - XGBoost**

# %% [markdown]
# #### **_Integrantes:_**
#
# 1. Evans Díaz
# 1. Felipe Ojeda
# 1. Javier Cofre
# 1. Luis Reinoso

# %%
# importar librerías
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import statsmodels.api as sm
import xgboost as xgb

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import randint, uniform
from matplotlib.ticker import EngFormatter

# %%
# función cálculo R2, RMSE y MSE
def R2_RMSE(y_true, y_pred):
  # cálculo de R2 y RMSE
  r2 = r2_score(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mse)
  
  return print('R2:',r2), print('RMSE:',rmse), print('MSE:', mse)

# %% [markdown]
# ## **_1. Lectura (carga) de los Datos_**

# %%
# importamos archivo
df = pd.read_csv('../Data/df_final_pay_sin_mt.csv')

# %%
# miramos el dataframe
df.head()
# Out:
#    year_2023  year_2024  month_2  month_3  month_4  month_5  month_6  month_7  \
# 0      False      False    False    False    False    False    False    False
# 1      False      False    False    False    False    False    False    False
# 2      False      False    False    False    False    False    False    False
# 3      False      False    False    False    False    False    False    False
# 4      False      False    False    False    False    False    False    False
#
#    month_8  month_9  ...  CAT 798-AC  KOM-CHQ  KOM.960E5  Kom.930E-4  \
# 0    False    False  ...         0.0      0.0       24.0        96.0
# 1    False    False  ...         0.0      0.0       24.0        96.0
# 2    False    False  ...         0.0      0.0       24.0        96.0
# 3    False    False  ...         0.0      0.0       24.0        95.0
# 4    False    False  ...         0.0      0.0       24.0        96.0
#
#    Kom.930E-4SE  Kom.930EN  Kom.930ER  Kom.930ER-MT  Kom.980E5  Komatsu AHS
# 0         395.0       96.0      240.0           0.0      132.0         24.0
# 1         396.0       96.0      240.0           0.0      132.0         24.0
# 2         394.0       96.0      240.0           0.0      132.0         24.0
# 3         396.0       96.0      240.0           0.0      132.0         24.0
# 4         395.0       96.0      240.0           0.0      132.0         24.0
#
# [5 rows x 84 columns]

# %%
# información general df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Data columns (total 84 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_2023            1567 non-null   bool
#  1   year_2024            1567 non-null   bool
#  2   month_2              1567 non-null   bool
#  3   month_3              1567 non-null   bool
#  4   month_4              1567 non-null   bool
#  5   month_5              1567 non-null   bool
#  6   month_6              1567 non-null   bool
#  7   month_7              1567 non-null   bool
#  8   month_8              1567 non-null   bool
#  9   month_9              1567 non-null   bool
#  10  month_10             1567 non-null   bool
#  11  month_11             1567 non-null   bool
#  12  month_12             1567 non-null   bool
#  13  day_2                1567 non-null   bool
#  14  day_3                1567 non-null   bool
#  15  day_4                1567 non-null   bool
#  16  day_5                1567 non-null   bool
#  17  day_6                1567 non-null   bool
#  18  day_7                1567 non-null   bool
#  19  day_8                1567 non-null   bool
#  20  day_9                1567 non-null   bool
#  21  day_10               1567 non-null   bool
#  22  day_11               1567 non-null   bool
#  23  day_12               1567 non-null   bool
#  24  day_13               1567 non-null   bool
#  25  day_14               1567 non-null   bool
#  26  day_15               1567 non-null   bool
#  27  day_16               1567 non-null   bool
#  28  day_17               1567 non-null   bool
#  29  day_18               1567 non-null   bool
#  30  day_19               1567 non-null   bool
#  31  day_20               1567 non-null   bool
#  32  day_21               1567 non-null   bool
#  33  day_22               1567 non-null   bool
#  34  day_23               1567 non-null   bool
#  35  day_24               1567 non-null   bool
#  36  day_25               1567 non-null   bool
#  37  day_26               1567 non-null   bool
#  38  day_27               1567 non-null   bool
#  39  day_28               1567 non-null   bool
#  40  day_29               1567 non-null   bool
#  41  day_30               1567 non-null   bool
#  42  day_31               1567 non-null   bool
#  43  shift_B              1567 non-null   bool
#  44  crew_E2              1567 non-null   bool
#  45  crew_E3              1567 non-null   bool
#  46  crew_E4              1567 non-null   bool
#  47  total                1567 non-null   float64
#  48  efectivo             1567 non-null   float64
#  49  mantencion           1567 non-null   float64
#  50  mecanica             1567 non-null   float64
#  51  electrica            1567 non-null   float64
#  52  mant_excl            1567 non-null   float64
#  53  mec_excl             1567 non-null   float64
#  54  elec_excl            1567 non-null   float64
#  55  som_excl             1567 non-null   float64
#  56  demora               1567 non-null   float64
#  57  r_prog               1567 non-null   float64
#  58  r_noprg              1567 non-null   float64
#  59  waiting              1567 non-null   int64
#  60  queued               1567 non-null   int64
#  61  payload              1567 non-null   float64
#  62  distance             1567 non-null   int64
#  63  distance_down        1567 non-null   int64
#  64  distance_down_level  1567 non-null   int64
#  65  distance_up          1567 non-null   int64
#  66  distance_up_level    1567 non-null   int64
#  67  expected_time        1567 non-null   int64
#  68  lift_down            1567 non-null   int64
#  69  lift_down_level      1567 non-null   int64
#  70  lift_up              1567 non-null   int64
#  71  lift_up_level        1567 non-null   int64
#  72  travel_time          1567 non-null   int64
#  73  CAT 797-F            1567 non-null   float64
#  74  CAT 798-AC           1567 non-null   float64
#  75  KOM-CHQ              1567 non-null   float64
#  76  KOM.960E5            1567 non-null   float64
#  77  Kom.930E-4           1567 non-null   float64
#  78  Kom.930E-4SE         1567 non-null   float64
#  79  Kom.930EN            1567 non-null   float64
#  80  Kom.930ER            1567 non-null   float64
#  81  Kom.930ER-MT         1567 non-null   float64
#  82  Kom.980E5            1567 non-null   float64
#  83  Komatsu AHS          1567 non-null   float64
# dtypes: bool(47), float64(24), int64(13)
# memory usage: 525.0 KB

# %% [markdown]
# ## **_2 Preparación del DataFrame_**

# %%
# transformamos las variables bool a categorical y le asignamos 0 o 1
for col in df.columns:
  if df[col].dtype == 'bool':
     df[col] = df[col].astype('category').cat.codes
     df[col] = df[col].astype('category') # para que quede como category y no como int8

# %%
print('Nombre Columnas: ',df.columns)
print('Cantidad Columnas: ',len(df.columns))
# Out:
# Nombre Columnas:  Index(['year_2023', 'year_2024', 'month_2', 'month_3', 'month_4', 'month_5',
#        'month_6', 'month_7', 'month_8', 'month_9', 'month_10', 'month_11',
#        'month_12', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'day_7',
#        'day_8', 'day_9', 'day_10', 'day_11', 'day_12', 'day_13', 'day_14',
#        'day_15', 'day_16', 'day_17', 'day_18', 'day_19', 'day_20', 'day_21',
#        'day_22', 'day_23', 'day_24', 'day_25', 'day_26', 'day_27', 'day_28',
#        'day_29', 'day_30', 'day_31', 'shift_B', 'crew_E2', 'crew_E3',
#        'crew_E4', 'total', 'efectivo', 'mantencion', 'mecanica', 'electrica',
#        'mant_excl', 'mec_excl', 'elec_excl', 'som_excl', 'demora', 'r_prog',
#        'r_noprg', 'waiting', 'queued', 'payload', 'distance', 'distance_down',
#        'distance_down_level', 'distance_up', 'distance_up_level',
#        'expected_time', 'lift_down', 'lift_down_level', 'lift_up',
#        'lift_up_level', 'travel_time', 'CAT 797-F', 'CAT 798-AC', 'KOM-CHQ',
#        'KOM.960E5', 'Kom.930E-4', 'Kom.930E-4SE', 'Kom.930EN', 'Kom.930ER',
#        'Kom.930ER-MT', 'Kom.980E5', 'Komatsu AHS'],
#       dtype='object')
# Cantidad Columnas:  84

# %%
# cálculamos la desviaicón estándar y la media de payload
std_y = df['payload'].std()
mean_y = df['payload'].mean()

print('Desviación Estándar:',std_y)
print('Media:',mean_y)
# Out:
# Desviación Estándar: 19936.05577427206
# Media: 142357.4639507874

# %%
# estandarizamos las variables numéricas
col_num = df.drop('payload', axis=1).select_dtypes(include=['float64','int64']).columns

scaler = StandardScaler()
df[col_num] = scaler.fit_transform(df[col_num])

# %% [markdown]
# ## **_3 XGBoost_**

# %%
# definimos el tamaño del set de test
test_size = 0.40

# %%
# separamos los datos en X e y
X = df.drop('payload', axis=1)
y = df['payload']

# dividimos los datos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
# Crear el modelo XGBoost
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', 
                             enable_categorical=True,
                             random_state=42)

# %%
# Entrenar el modelo
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
predictions_train = xgb_model.predict(X_train)

# %%
# resultados de R2, RMSE y MSE
R2_RMSE(y_train, predictions_train)
# Out:
# R2: 0.9999310426826591
# RMSE: 166.74220955661025
# MSE: 27802.964447820526
# (None, None, None)

# %%
# Realizar predicciones con el modelo entrenado
predictions_test = xgb_model.predict(X_test)

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test, predictions_test)
# Out:
# R2: 0.6520144148527937
# RMSE: 11622.037913799262
# MSE: 135071765.26978752
# (None, None, None)

# %% [markdown]
# ## _4 Optimización del Modelo_

# %% [markdown]
# ### _4.1 Selección de Variables (LassoCV)_

# %%
# buscamos alpha optimo con LassoCV
alpha_values = np.linspace(0.01, 300, 30000)

# Crea un objeto LassoCV
lasso_cv = LassoCV(alphas=alpha_values, cv=5)

# Ajusta el modelo a los datos de entrenamiento
lasso_cv.fit(X_train, y_train)

# Valor óptimo de alpha
best_alpha = lasso_cv.alpha_

# Evalúa el modelo en el conjunto de prueba
score = lasso_cv.score(X_test, y_test)

print(f"Mejor valor de alpha: {best_alpha}")
print(f"Puntuación en el conjunto de prueba: {score}")
# Out:
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35274870.35211182, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43757697.01319885, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51165916.08050537, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57504167.0473938, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62866933.26847839, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67377680.90661621, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71164223.16485596, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74346468.57943726, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77031073.42831421, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79309872.6003418, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81260266.35324097, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82946535.71743774, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84421508.77911377, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85728273.97390747, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86901780.54501343, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87970259.22201538, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88956442.83511353, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89878600.07749939, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90751388.5388031, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91586557.12374878, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92393520.34518433, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93179820.7864685, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93951507.29367065, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94713429.075943, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95469488.51812744, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96222822.83340454, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96975969.65498352, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97862259.90005493, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98641283.0623169, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99417316.10392761, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100197210.66714478, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100982366.83000183, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101773929.384552, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102572848.15057373, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103379923.94140625, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104195837.79379272, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105021176.48649597, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105856454.33084106, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106702127.38789368, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107558607.07479858, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108426271.68399048, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109305472.67941284, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110196541.96661377, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111099797.86495972, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112015549.13122559, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112944096.67948914, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113885738.18508911, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114840772.11831665, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115809492.8762207, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116792201.37374878, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117789197.27893066, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118800788.25378418, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119827284.03297424, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120869001.69552612, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91512754.39312744, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60119170.96801758, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47085652.46946716, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41406062.263671875, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38907639.650634766, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37867220.08387756, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37518816.1423645, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37506004.62916565, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37658704.46279907, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37894703.01867676, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38174025.51953125, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38477200.90698242, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38794759.99839783, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39122127.942596436, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45440375.04727173, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62924912.51409912, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79524914.74923706, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94197004.45471191, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106908392.80526733, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117801749.15390015, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127091491.07518005, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135016156.7094574, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141794484.79566956, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147621560.55639648, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152674862.96098328, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157102820.12698364, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161029468.92282104, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164557330.2345276, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167770482.90490723, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170737499.6580963, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173514090.16918945, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176145401.23214722, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178667961.31121826, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181111312.92971802, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 183499352.99017334, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185851436.9760437, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188183272.77703857, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 190507647.82128906, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192835015.6510315, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195173967.75759888, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197531614.26690674, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199913888.00231934, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202325789.4773407, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204771583.93580627, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 207254958.09033203, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209779146.04536438, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212347030.37017822, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 214961224.20091248, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217624135.78475952, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 220338021.7088623, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 223105030.2017975, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225927231.90737915, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 228806653.54257202, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231745296.56436157, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234745157.5369873, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 237808242.7290039, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 240936586.08169556, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244132253.15863037, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247397356.25448608, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250734059.3864441, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254144589.45466614, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265749900.58213806, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184445269.80456543, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132960038.61036682, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155394312.35687256, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180718812.34939575, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202805185.5470581, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 221953302.78341675, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 238553201.69548035, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253001634.46487427, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265668053.0001526, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276880358.24472046, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 286921216.81062317, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 296029748.98365784, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304405727.5742798, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312214654.0549011, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319592895.8928833, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326652456.51556396, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333485201.54634094, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340166502.21191406, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 346758309.59591675, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 353311712.54382324, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 359869060.7767029, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 366465696.7128296, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 373131372.7963562, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379891402.88830566, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386767602.20254517, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 393749757.8801575, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 400871943.2042694, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 408182414.14256287, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 415678141.79196167, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423371561.64712524, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 431274694.98957825, tolerance: 29751362.65422229
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439399290.6374817, tolerance: 29751362.65422229
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1194791680.8762665, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1236181104.5152283, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1279812567.9065857, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1325850833.887329, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1374476136.3099365, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1425885949.1828232, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1480296987.6520844, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1537947486.5087128, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1599099831.077835, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1664043526.4836578, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1733098653.8561096, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1806619777.2105713, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1885000581.0465546, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1968802997.0033417, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2058503491.1533585, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2154521232.6236877, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2257458462.2071915, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2368008072.3042603, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2486949565.1530685, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2615162719.0163116, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2753643952.627014, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2903525739.7181244, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3066099800.2018814, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3242845065.3428802, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3435461374.4311523, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3645910518.417557, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3876466343.4229736, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4129776382.548378, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4408938248.752762, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4717594682.368729, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5060052988.924339, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441436040.616692, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5867874948.916199, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6346756989.89386, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6887047507.652687, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7499712512.078575, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8198279476.262444, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8999590148.268272, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9924825032.510468, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11000917284.68248, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12262534477.346527, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13754905533.762642, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15537930669.230118, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17692285770.316956, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20328709381.950073, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23602519790.939003, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27737021200.02871, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/evansdl/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33062609672.713993, tolerance: 30679684.749391723
#   model = cd_fast.enet_coordinate_descent_gram(
# Mejor valor de alpha: 64.59
# Puntuación en el conjunto de prueba: 0.7100250304345364

# %%
# Graficar MSE vs. Alpha
plt.figure(figsize=(10,6))
plt.plot(lasso_cv.alphas_, np.mean(lasso_cv.mse_path_, axis=1), '-o')
plt.xlabel('Alpha')
plt.ylabel('Mean MSE across CV folds')
plt.title('Path de Regularización')
plt.axvline(lasso_cv.alpha_, color='red', linestyle='--')

# Anotar el valor óptimo de alpha en el gráfico
plt.annotate(f'Optimal alpha: {lasso_cv.alpha_:.2f}, MSE: {np.min(np.mean(lasso_cv.mse_path_, axis=1)):.2f}',
             xy=(lasso_cv.alpha_, np.min(np.mean(lasso_cv.mse_path_, axis=1))),
             xycoords='data', xytext=(10,100), 
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1.5),
             fontsize=9)

plt.show()

# %%
# Aplicar Lasso para la selección de características
lasso = Lasso(alpha=lasso_cv.alpha_)  
lasso.fit(X_train, y_train)

# Seleccionar las características que tienen coeficientes no nulos
selected_features = X_train.columns[lasso.coef_ != 0]

print("Características seleccionadas:")
print(selected_features)
# Out:
# Características seleccionadas:
# Index(['year_2024', 'month_3', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_11', 'day_2', 'day_3', 'day_4', 'day_5', 'day_17', 'day_19',
#        'day_22', 'day_23', 'day_26', 'day_27', 'day_28', 'day_30', 'shift_B',
#        'crew_E2', 'crew_E4', 'efectivo', 'mecanica', 'electrica', 'mant_excl',
#        'mec_excl', 'elec_excl', 'demora', 'r_noprg', 'waiting', 'queued',
#        'distance_down_level', 'distance_up', 'distance_up_level',
#        'expected_time', 'lift_down', 'lift_down_level', 'lift_up_level',
#        'travel_time', 'CAT 797-F', 'CAT 798-AC', 'KOM-CHQ', 'KOM.960E5',
#        'Kom.930E-4', 'Kom.930EN', 'Kom.930ER', 'Kom.930ER-MT', 'Kom.980E5',
#        'Komatsu AHS'],
#       dtype='object')

# %%
len(selected_features)
# Out:
# 50

# %% [markdown]
# > Volvemos ajustar el modelo con las variables seleccionadas

# %%
# separamos los datos en train y test
X_lasso= df[selected_features]
y_lasso = df['payload']

# dividimos los datos en train y test
X_train_lasso, X_test_lasso, y_train_lasso, y_test_lasso = train_test_split(X_lasso, y_lasso, test_size=test_size, random_state=42)

# %%
# Inicializar el regresor AdaBoost
xgb_model_lasso = xgb.XGBRegressor(objective='reg:squarederror', 
                                   enable_categorical=True,
                                   random_state=42)

# %%
# Entrenar el modelo AdaBoost
xgb_model_lasso.fit(X_train_lasso, y_train_lasso)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# #### 4.1.1 Predicciones en el conjunto de entrenamiento

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_train = xgb_model_lasso.predict(X_train_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_train_lasso, predictions_lasso_train)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 75148.59

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_train_lasso, predictions_lasso_train)
# Out:
# R2: 0.9998136153823491
# RMSE: 274.13242435334337
# MSE: 75148.58608184152
# (None, None, None)

# %% [markdown]
# #### 4.1.2 Predicciones en el conjunto de testeo

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_test = xgb_model_lasso.predict(X_test_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_test_lasso, predictions_lasso_test)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 136901761.23

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test_lasso, predictions_lasso_test)
# Out:
# R2: 0.647299793600212
# RMSE: 11700.502605887597
# MSE: 136901761.23038247
# (None, None, None)

# %% [markdown]
# ### _4.2 Optimización de Hiperparámetros_

# %%
# Definir los hiperparámetros para la búsqueda
param_dist_xgb = {
    'n_estimators': randint(50, 500),
    'learning_rate': uniform(0.01, 0.6),
    'subsample': uniform(0.3, 0.7),
    'max_depth': randint(1, 20),
    'colsample_bytree': uniform(0.5, 0.5),
    'gamma': uniform(0, 0.5),
    'reg_alpha': uniform(0, 1),  # L1 regularization term
    'reg_lambda': uniform(1, 4)  # L2 regularization term
}

# Crear el modelo XGBoost
xgb_model_hip= xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42)

# Crear la búsqueda de hiperparámetros
random_search_xgb = RandomizedSearchCV(
    estimator=xgb_model_hip,
    param_distributions=param_dist_xgb,
    n_iter=100,
    cv=5,
    scoring='r2',
    random_state=42,
    n_jobs=-1
)

# Ajustar el modelo
random_search_xgb.fit(X_train_lasso, y_train_lasso)

# Obtener los mejores hiperparámetros
best_params_xgb = random_search_xgb.best_params_
print("Best parameters for XGBoost: ", best_params_xgb)
# Out:
# Best parameters for XGBoost:  {'colsample_bytree': 0.7458079375584161, 'gamma': 0.23673588539028284, 'learning_rate': 0.1139211219460091, 'max_depth': 5, 'n_estimators': 72, 'reg_alpha': 0.048058924197033726, 'reg_lambda': 4.796582926365543, 'subsample': 0.9206762711086331}

# %%
# Crear el modelo XGBoost con los mejores hiperparámetros
xgb_model_best = xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42,
                             **best_params_xgb)

# %%
# Entrenar el modelo con los mejores hiperparámetros
xgb_model_best.fit(X_train_lasso, y_train_lasso,
                   eval_set=[(X_test_lasso, y_test_lasso)],
                   #early_stopping_rounds=10,
                   verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7458079375584161, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=0.23673588539028284,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1139211219460091,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=72, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
train_predictions = xgb_model_best.predict(X_train_lasso)

# Realizar predicciones en el conjunto de prueba
test_predictions = xgb_model_best.predict(X_test_lasso)

# %%
# Evaluar el modelo en el conjunto de entrenamiento
train_r2 = r2_score(y_train_lasso, train_predictions)
train_mse = mean_squared_error(y_train_lasso, train_predictions)
train_rmse = np.sqrt(train_mse)

print(f"R2 en el conjunto de entrenamiento: {train_r2:.3f}")
print(f"MSE en el conjunto de entrenamiento: {train_mse:.2f}")
print(f"RMSE en el conjunto de entrenamiento: {train_rmse:.2f}")
# Out:
# R2 en el conjunto de entrenamiento: 0.927
# MSE en el conjunto de entrenamiento: 29236613.70
# RMSE en el conjunto de entrenamiento: 5407.09

# %%
# Evaluar el modelo en el conjunto de prueba
test_r2 = r2_score(y_test_lasso, test_predictions)
test_mse = mean_squared_error(y_test_lasso, test_predictions)
test_rmse = np.sqrt(test_mse)

print(f"R2 en el conjunto de prueba: {test_r2:.3f}")
print(f"MSE en el conjunto de prueba: {test_mse:.2f}")
print(f"RMSE en el conjunto de prueba: {test_rmse:.2f}")
# Out:
# R2 en el conjunto de prueba: 0.690
# MSE en el conjunto de prueba: 120289147.77
# RMSE en el conjunto de prueba: 10967.64

# %% [markdown]
# ### _4.3 Graficamos los hiperparámetros_

# %%
# Convertir cv_results_ a un DataFrame de pandas
results_df = pd.DataFrame(random_search_xgb.cv_results_)

# Mostrar el DataFrame
results_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.065101      0.404151         0.105424        0.044614
# 1       0.527976      0.185607         0.081847        0.070582
# 2      10.733040      0.665558         0.103606        0.027432
# 3       9.296335      0.541999         0.123487        0.056540
# 4       6.065931      0.293962         0.107706        0.064016
#
#    param_colsample_bytree  param_gamma  param_learning_rate  param_max_depth  \
# 0                0.687270     0.475357             0.449196                7
# 1                0.800558     0.354036             0.022351                2
# 2                0.591702     0.152121             0.324854               12
# 3                0.646072     0.183181             0.283642               15
# 4                0.523225     0.303772             0.112314                7
#
#    param_n_estimators  param_reg_alpha  ...  param_subsample  \
# 0                 171         0.155995  ...         0.906323
# 1                 393         0.832443  ...         0.427277
# 2                 394         0.291229  ...         0.397646
# 3                 495         0.199674  ...         0.714690
# 4                 323         0.948886  ...         0.865878
#
#                                               params split0_test_score  \
# 0  {'colsample_bytree': 0.6872700594236812, 'gamm...          0.642013
# 1  {'colsample_bytree': 0.8005575058716043, 'gamm...          0.702583
# 2  {'colsample_bytree': 0.5917022549267169, 'gamm...          0.570932
# 3  {'colsample_bytree': 0.6460723242676091, 'gamm...          0.632471
# 4  {'colsample_bytree': 0.5232252063599989, 'gamm...          0.711160
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.558553           0.409148           0.595049           0.606069
# 1           0.632213           0.529463           0.683195           0.652787
# 2           0.539984           0.324722           0.543566           0.564678
# 3           0.561795           0.455153           0.607354           0.601426
# 4           0.616412           0.543948           0.671757           0.641028
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.562166        0.081009               56
# 1         0.640048        0.060374                6
# 2         0.508776        0.092788               77
# 3         0.571640        0.062497               50
# 4         0.636861        0.056225               12
#
# [5 rows x 21 columns]

# %%
results_df.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_colsample_bytree', 'param_gamma', 'param_learning_rate',
#        'param_max_depth', 'param_n_estimators', 'param_reg_alpha',
#        'param_reg_lambda', 'param_subsample', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'mean_test_score', 'std_test_score',
#        'rank_test_score'],
#       dtype='object')

# %% [markdown]
# #### 4.3.1 Gráfica de learning_rate vs. n_estimators

# %%
# graficar la relación entre el RMSE y los valores de los hiperparámetros
plt.figure(figsize=(10,6))
sns.scatterplot(data=results_df, x='param_learning_rate', y='mean_test_score', hue='param_n_estimators', palette='viridis')

# mejoramos la visualización
#plt.title('Mean Test Score vs. Learning Rate')
plt.xlabel('Learning Rate')
plt.ylabel('Mean Test Score')
plt.legend(title='Número de Estimadores')
sns.despine()

# anotamos el mejor valor de learning rate
plt.annotate(f'Best Learning Rate: {best_params_xgb["learning_rate"]:.2f}',
             xy=(best_params_xgb['learning_rate'], random_search_xgb.best_score_),
             xycoords='data', xytext=(10,10), 
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1.5),
             fontsize=9)
plt.show()
