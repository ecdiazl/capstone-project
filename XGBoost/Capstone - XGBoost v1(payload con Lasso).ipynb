# %% [markdown]
# ## **Capstone MDS - XGBoost**

# %% [markdown]
# #### **_Integrantes:_**
#
# 1. Evans Díaz
# 1. Felipe Ojeda
# 1. Javier Cofre
# 1. Luis Reinoso

# %%
# importar librerías
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import statsmodels.api as sm
import xgboost as xgb

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import randint, uniform
from matplotlib.ticker import EngFormatter

# %%
# función cálculo R2, RMSE y MSE
def R2_RMSE(y_true, y_pred):
  # cálculo de R2 y RMSE
  r2 = r2_score(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mse)
  
  return print('R2:',r2), print('RMSE:',rmse), print('MSE:', mse)

# %% [markdown]
# ## **_1. Lectura (carga) de los Datos_**

# %%
# importamos archivo
df = pd.read_csv('../Data/df_final_pay_sin_mt.csv')

# %%
# miramos el dataframe
df.head()
# Out:
#    year_2023  year_2024  month_2  month_3  month_4  month_5  month_6  month_7  \
# 0      False      False    False    False    False    False    False    False
# 1      False      False    False    False    False    False    False    False
# 2      False      False    False    False    False    False    False    False
# 3      False      False    False    False    False    False    False    False
# 4      False      False    False    False    False    False    False    False
#
#    month_8  month_9  ...  CAT 798-AC  KOM-CHQ  KOM.960E5  Kom.930E-4  \
# 0    False    False  ...         0.0      0.0       24.0        96.0
# 1    False    False  ...         0.0      0.0       24.0        96.0
# 2    False    False  ...         0.0      0.0       24.0        96.0
# 3    False    False  ...         0.0      0.0       24.0        95.0
# 4    False    False  ...         0.0      0.0       24.0        96.0
#
#    Kom.930E-4SE  Kom.930EN  Kom.930ER  Kom.930ER-MT  Kom.980E5  Komatsu AHS
# 0         395.0       96.0      240.0           0.0      132.0         24.0
# 1         396.0       96.0      240.0           0.0      132.0         24.0
# 2         394.0       96.0      240.0           0.0      132.0         24.0
# 3         396.0       96.0      240.0           0.0      132.0         24.0
# 4         395.0       96.0      240.0           0.0      132.0         24.0
#
# [5 rows x 84 columns]

# %%
# información general df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Data columns (total 84 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_2023            1567 non-null   bool
#  1   year_2024            1567 non-null   bool
#  2   month_2              1567 non-null   bool
#  3   month_3              1567 non-null   bool
#  4   month_4              1567 non-null   bool
#  5   month_5              1567 non-null   bool
#  6   month_6              1567 non-null   bool
#  7   month_7              1567 non-null   bool
#  8   month_8              1567 non-null   bool
#  9   month_9              1567 non-null   bool
#  10  month_10             1567 non-null   bool
#  11  month_11             1567 non-null   bool
#  12  month_12             1567 non-null   bool
#  13  day_2                1567 non-null   bool
#  14  day_3                1567 non-null   bool
#  15  day_4                1567 non-null   bool
#  16  day_5                1567 non-null   bool
#  17  day_6                1567 non-null   bool
#  18  day_7                1567 non-null   bool
#  19  day_8                1567 non-null   bool
#  20  day_9                1567 non-null   bool
#  21  day_10               1567 non-null   bool
#  22  day_11               1567 non-null   bool
#  23  day_12               1567 non-null   bool
#  24  day_13               1567 non-null   bool
#  25  day_14               1567 non-null   bool
#  26  day_15               1567 non-null   bool
#  27  day_16               1567 non-null   bool
#  28  day_17               1567 non-null   bool
#  29  day_18               1567 non-null   bool
#  30  day_19               1567 non-null   bool
#  31  day_20               1567 non-null   bool
#  32  day_21               1567 non-null   bool
#  33  day_22               1567 non-null   bool
#  34  day_23               1567 non-null   bool
#  35  day_24               1567 non-null   bool
#  36  day_25               1567 non-null   bool
#  37  day_26               1567 non-null   bool
#  38  day_27               1567 non-null   bool
#  39  day_28               1567 non-null   bool
#  40  day_29               1567 non-null   bool
#  41  day_30               1567 non-null   bool
#  42  day_31               1567 non-null   bool
#  43  shift_B              1567 non-null   bool
#  44  crew_E2              1567 non-null   bool
#  45  crew_E3              1567 non-null   bool
#  46  crew_E4              1567 non-null   bool
#  47  total                1567 non-null   float64
#  48  efectivo             1567 non-null   float64
#  49  mantencion           1567 non-null   float64
#  50  mecanica             1567 non-null   float64
#  51  electrica            1567 non-null   float64
#  52  mant_excl            1567 non-null   float64
#  53  mec_excl             1567 non-null   float64
#  54  elec_excl            1567 non-null   float64
#  55  som_excl             1567 non-null   float64
#  56  demora               1567 non-null   float64
#  57  r_prog               1567 non-null   float64
#  58  r_noprg              1567 non-null   float64
#  59  waiting              1567 non-null   int64
#  60  queued               1567 non-null   int64
#  61  payload              1567 non-null   float64
#  62  distance             1567 non-null   int64
#  63  distance_down        1567 non-null   int64
#  64  distance_down_level  1567 non-null   int64
#  65  distance_up          1567 non-null   int64
#  66  distance_up_level    1567 non-null   int64
#  67  expected_time        1567 non-null   int64
#  68  lift_down            1567 non-null   int64
#  69  lift_down_level      1567 non-null   int64
#  70  lift_up              1567 non-null   int64
#  71  lift_up_level        1567 non-null   int64
#  72  travel_time          1567 non-null   int64
#  73  CAT 797-F            1567 non-null   float64
#  74  CAT 798-AC           1567 non-null   float64
#  75  KOM-CHQ              1567 non-null   float64
#  76  KOM.960E5            1567 non-null   float64
#  77  Kom.930E-4           1567 non-null   float64
#  78  Kom.930E-4SE         1567 non-null   float64
#  79  Kom.930EN            1567 non-null   float64
#  80  Kom.930ER            1567 non-null   float64
#  81  Kom.930ER-MT         1567 non-null   float64
#  82  Kom.980E5            1567 non-null   float64
#  83  Komatsu AHS          1567 non-null   float64
# dtypes: bool(47), float64(24), int64(13)
# memory usage: 525.0 KB

# %% [markdown]
# ## **_2 Preparación del DataFrame_**

# %%
# transformamos las variables bool a categorical y le asignamos 0 o 1
for col in df.columns:
  if df[col].dtype == 'bool':
     df[col] = df[col].astype('category').cat.codes
     df[col] = df[col].astype('category') # para que quede como category y no como int8

# %%
print('Nombre Columnas: ',df.columns)
print('Cantidad Columnas: ',len(df.columns))
# Out:
# Nombre Columnas:  Index(['year_2023', 'year_2024', 'month_2', 'month_3', 'month_4', 'month_5',
#        'month_6', 'month_7', 'month_8', 'month_9', 'month_10', 'month_11',
#        'month_12', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'day_7',
#        'day_8', 'day_9', 'day_10', 'day_11', 'day_12', 'day_13', 'day_14',
#        'day_15', 'day_16', 'day_17', 'day_18', 'day_19', 'day_20', 'day_21',
#        'day_22', 'day_23', 'day_24', 'day_25', 'day_26', 'day_27', 'day_28',
#        'day_29', 'day_30', 'day_31', 'shift_B', 'crew_E2', 'crew_E3',
#        'crew_E4', 'total', 'efectivo', 'mantencion', 'mecanica', 'electrica',
#        'mant_excl', 'mec_excl', 'elec_excl', 'som_excl', 'demora', 'r_prog',
#        'r_noprg', 'waiting', 'queued', 'payload', 'distance', 'distance_down',
#        'distance_down_level', 'distance_up', 'distance_up_level',
#        'expected_time', 'lift_down', 'lift_down_level', 'lift_up',
#        'lift_up_level', 'travel_time', 'CAT 797-F', 'CAT 798-AC', 'KOM-CHQ',
#        'KOM.960E5', 'Kom.930E-4', 'Kom.930E-4SE', 'Kom.930EN', 'Kom.930ER',
#        'Kom.930ER-MT', 'Kom.980E5', 'Komatsu AHS'],
#       dtype='object')
# Cantidad Columnas:  84

# %%
# cálculamos la desviaicón estándar y la media de payload
std_y = df['payload'].std()
mean_y = df['payload'].mean()

print('Desviación Estándar:',std_y)
print('Media:',mean_y)
# Out:
# Desviación Estándar: 19936.05577427206
# Media: 142357.4639507874

# %%
# estandarizamos las variables numéricas
col_num = df.drop('payload', axis=1).select_dtypes(include=['float64','int64']).columns

scaler = StandardScaler()
df[col_num] = scaler.fit_transform(df[col_num])

# %% [markdown]
# ## **_3 XGBoost_**

# %%
# definimos el tamaño del set de test
test_size = 0.40

# %%
# separamos los datos en X e y
X = df.drop('payload', axis=1)
y = df['payload']

# dividimos los datos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# %%
# Crear el modelo XGBoost
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', 
                             enable_categorical=True,
                             random_state=42)

# %%
# Entrenar el modelo
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
predictions_train = xgb_model.predict(X_train)

# %%
# resultados de R2, RMSE y MSE
R2_RMSE(y_train, predictions_train)
# Out:
# R2: 0.9999310426826591
# RMSE: 166.74220955661028
# MSE: 27802.964447820534
# (None, None, None)

# %%
# Realizar predicciones con el modelo entrenado
predictions_test = xgb_model.predict(X_test)

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test, predictions_test)
# Out:
# R2: 0.6520144148527937
# RMSE: 11622.037913799262
# MSE: 135071765.26978752
# (None, None, None)

# %% [markdown]
# ## _4 Optimización del Modelo_

# %% [markdown]
# ### _4.1 Selección de Variables (LassoCV)_

# %%
# buscamos alpha optimo con LassoCV
alpha_values = np.linspace(0.01, 300, 30000)

# Crea un objeto LassoCV
lasso_cv = LassoCV(alphas=alpha_values, cv=5)

# Ajusta el modelo a los datos de entrenamiento
lasso_cv.fit(X_train, y_train)

# Valor óptimo de alpha
best_alpha = lasso_cv.alpha_

# Evalúa el modelo en el conjunto de prueba
score = lasso_cv.score(X_test, y_test)

print(f"Mejor valor de alpha: {best_alpha}")
print(f"Puntuación en el conjunto de prueba: {score}")
# Out:
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35274870.46110535, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43757696.89682007, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51165916.41699219, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57504166.98956299, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62866933.072647095, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67377680.92550659, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71164223.54933167, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74346468.5884552, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77031073.0735321, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79309872.81185913, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81260266.68565369, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82946535.5291748, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84421508.46313477, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85728273.88258362, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86901780.85005188, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87970259.29743958, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88956442.81903076, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89878600.08766174, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90751388.55278015, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91586556.92628479, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92393520.2227478, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93179820.70275879, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93951507.08221436, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94713429.10545349, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95469488.51602173, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96222822.57608032, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96975969.53503418, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97862260.14015198, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98641283.00695801, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99417316.09268188, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100197210.8678894, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100982366.66836548, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101773929.33865356, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102572848.13858032, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103379923.87860107, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104195837.74205017, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105021176.54853821, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105856454.21562195, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106702127.45768738, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107558607.27670288, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108426271.66921997, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109305472.37748718, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110196541.8666687, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111099798.06112671, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112015548.87080383, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112944096.5340271, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113885738.10714722, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114840772.11541748, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115809492.9655304, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116792201.20639038, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117789197.23330688, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118800788.10531616, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119827284.18252563, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120869001.58892822, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91512754.2339325, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60119170.94129944, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47085652.31628418, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41406062.22050476, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38907639.69786072, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37867220.2086792, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37518816.19332886, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37506004.703552246, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37658704.48510742, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37894702.93383789, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38174025.55999756, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38477200.74177551, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38794760.17376709, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39122127.9670105, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45440374.82136536, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62924912.49861145, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79524914.75834656, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94197004.61991882, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106908393.50450134, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 117801749.29988098, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127091491.09759521, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135016156.4574585, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141794485.12806702, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 147621560.23669434, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152674863.3648224, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157102820.39138794, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161029469.12332153, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164557330.5150299, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167770482.43946838, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170737499.41799927, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173514089.99160767, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 176145401.375412, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 178667961.6204071, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181111312.7407074, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 183499353.19708252, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185851436.62745667, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188183273.00099182, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 190507647.8761444, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192835015.29426575, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195173967.4949646, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197531613.69561768, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199913887.6622162, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202325789.71374512, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204771584.24699402, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 207254958.24693298, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209779145.6105652, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212347030.45033264, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 214961224.29560852, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217624135.78929138, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 220338021.97540283, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 223105030.03408813, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225927232.02166748, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 228806653.5527954, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231745296.16534424, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234745157.43830872, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 237808242.60890198, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 240936586.5384369, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244132253.24983215, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247397355.2992401, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250734058.7110901, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254144590.19519043, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265749901.32032776, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184445270.5274353, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132960038.77580261, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 155394312.65452576, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180718812.22244263, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202805185.57974243, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 221953301.9024048, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 238553201.40293884, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253001634.16337585, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265668052.80117798, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276880358.85014343, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 286921216.1923065, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 296029749.75035095, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304405727.52622986, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312214654.4448242, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319592895.9274597, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326652456.4580078, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333485201.5758362, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340166502.115448, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 346758308.882843, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 353311712.40382385, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 359869060.9334259, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 366465696.10697937, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 373131371.90267944, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379891402.8067322, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386767601.38819885, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 393749759.0513153, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 400871941.49168396, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 408182413.97325134, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 415678141.3400421, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 423371560.93218994, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 431274695.2330475, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439399290.94111633, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 447756988.3340149, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 456359452.8303375, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 465218493.8713989, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 474346167.9772186, tolerance: 29751362.65422227
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1118148058.7484741, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1155493435.5585785, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1194791683.0632095, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1236181109.960991, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1279812563.54422, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1325850829.973114, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1374476134.1646729, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1425885947.4822235, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1480296985.569374, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1537947488.3250809, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1599099832.8637161, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1664043528.7288818, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1733098650.3986053, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1806619781.9322052, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1885000579.7242126, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1968802997.2724304, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2058503483.2481766, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2154521233.284088, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2257458459.670738, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2368008076.6915665, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2486949567.1138, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2615162721.1087036, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2753643959.988701, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2903525736.16584, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3066099791.164978, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3242845068.4757843, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3435461378.016533, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3645910525.9956665, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3876466339.882942, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4129776383.743431, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4408938252.217567, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4717594678.415955, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5060052986.803284, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5441436043.024826, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5867874973.314743, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6346756999.558472, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6887047497.250954, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7499712522.844147, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8198279482.786407, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8999590132.374512, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9924825051.248062, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11000917295.7053, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12262534472.12815, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13754905528.624603, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15537930665.702991, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17692285785.0487, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20328709372.418884, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23602519803.598774, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27737021193.13383, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33062609670.967068, tolerance: 30679684.74939174
#   model = cd_fast.enet_coordinate_descent_gram(
# Mejor valor de alpha: 64.59
# Puntuación en el conjunto de prueba: 0.7100250304345364

# %%
# Graficar MSE vs. Alpha
plt.figure(figsize=(10,6))
plt.plot(lasso_cv.alphas_, np.mean(lasso_cv.mse_path_, axis=1), '-o')
plt.xlabel('Alpha')
plt.ylabel('Mean MSE across CV folds')
plt.title('Path de Regularización')
plt.axvline(lasso_cv.alpha_, color='red', linestyle='--')

# Anotar el valor óptimo de alpha en el gráfico
plt.annotate(f'Optimal alpha: {lasso_cv.alpha_:.2f}, MSE: {np.min(np.mean(lasso_cv.mse_path_, axis=1)):.2f}',
             xy=(lasso_cv.alpha_, np.min(np.mean(lasso_cv.mse_path_, axis=1))),
             xycoords='data', xytext=(10,100), 
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1.5),
             fontsize=9)

plt.show()

# %%
# Aplicar Lasso para la selección de características
lasso = Lasso(alpha=lasso_cv.alpha_)  
lasso.fit(X_train, y_train)

# Seleccionar las características que tienen coeficientes no nulos
selected_features = X_train.columns[lasso.coef_ != 0]

print("Características seleccionadas:")
print(selected_features)
# Out:
# Características seleccionadas:
# Index(['year_2024', 'month_3', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_11', 'day_2', 'day_3', 'day_4', 'day_5', 'day_17', 'day_19',
#        'day_22', 'day_23', 'day_26', 'day_27', 'day_28', 'day_30', 'shift_B',
#        'crew_E2', 'crew_E4', 'efectivo', 'mecanica', 'electrica', 'mant_excl',
#        'mec_excl', 'elec_excl', 'demora', 'r_noprg', 'waiting', 'queued',
#        'distance_down_level', 'distance_up', 'distance_up_level',
#        'expected_time', 'lift_down', 'lift_down_level', 'lift_up_level',
#        'travel_time', 'CAT 797-F', 'CAT 798-AC', 'KOM-CHQ', 'KOM.960E5',
#        'Kom.930E-4', 'Kom.930EN', 'Kom.930ER', 'Kom.930ER-MT', 'Kom.980E5',
#        'Komatsu AHS'],
#       dtype='object')

# %%
len(selected_features)
# Out:
# 50

# %% [markdown]
# > Volvemos ajustar el modelo con las variables seleccionadas

# %%
# separamos los datos en train y test
X_lasso= df[selected_features]
y_lasso = df['payload']

# dividimos los datos en train y test
X_train_lasso, X_test_lasso, y_train_lasso, y_test_lasso = train_test_split(X_lasso, y_lasso, test_size=test_size, random_state=42)

# %%
# Inicializar el regresor AdaBoost
xgb_model_lasso = xgb.XGBRegressor(objective='reg:squarederror', 
                                   enable_categorical=True,
                                   random_state=42)

# %%
# Entrenar el modelo AdaBoost
xgb_model_lasso.fit(X_train_lasso, y_train_lasso)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# #### 4.1.1 Predicciones en el conjunto de entrenamiento

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_train = xgb_model_lasso.predict(X_train_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_train_lasso, predictions_lasso_train)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 75148.59

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_train_lasso, predictions_lasso_train)
# Out:
# R2: 0.9998136153823491
# RMSE: 274.13242435334337
# MSE: 75148.58608184152
# (None, None, None)

# %% [markdown]
# #### 4.1.2 Predicciones en el conjunto de testeo

# %%
# Realizar predicciones con el modelo entrenado
predictions_lasso_test = xgb_model_lasso.predict(X_test_lasso)

# %%
# Evaluar la precisión del modelo
mse = mean_squared_error(y_test_lasso, predictions_lasso_test)
print(f'Mean Squared Error of AdaBoost Regressor: {mse:.2f}')
# Out:
# Mean Squared Error of AdaBoost Regressor: 136901761.23

# %%
# resultado de R2, RMSE y MSE
R2_RMSE(y_test_lasso, predictions_lasso_test)
# Out:
# R2: 0.647299793600212
# RMSE: 11700.502605887597
# MSE: 136901761.23038247
# (None, None, None)

# %% [markdown]
# ### _4.2 Optimización de Hiperparámetros_

# %%
# Definir los hiperparámetros para la búsqueda
param_dist_xgb = {
    'n_estimators': randint(50, 500),
    'learning_rate': uniform(0.01, 0.6),
    'subsample': uniform(0.3, 0.7),
    'max_depth': randint(1, 20),
    'colsample_bytree': uniform(0.5, 0.5),
    'gamma': uniform(0, 0.5),
    'reg_alpha': uniform(0, 1),  # L1 regularization term
    'reg_lambda': uniform(1, 4)  # L2 regularization term
}

# Crear el modelo XGBoost
xgb_model_hip= xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42)

# Crear la búsqueda de hiperparámetros
random_search_xgb = RandomizedSearchCV(
    estimator=xgb_model_hip,
    param_distributions=param_dist_xgb,
    n_iter=100,
    cv=5,
    scoring='r2',
    random_state=42,
    n_jobs=-1
)

# Ajustar el modelo
random_search_xgb.fit(X_train_lasso, y_train_lasso)

# Obtener los mejores hiperparámetros
best_params_xgb = random_search_xgb.best_params_
print("Best parameters for XGBoost: ", best_params_xgb)
# Out:
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best parameters for XGBoost:  {'colsample_bytree': 0.6299749314271313, 'gamma': 0.22662042341441552, 'learning_rate': 0.02938957066579028, 'max_depth': 9, 'n_estimators': 466, 'reg_alpha': 0.41120672087218624, 'reg_lambda': 3.411127528093194, 'subsample': 0.4896703497605909}

# %%
# Crear el modelo XGBoost con los mejores hiperparámetros
xgb_model_best = xgb.XGBRegressor(objective='reg:squarederror',
                             enable_categorical=True,
                             random_state=42,
                             **best_params_xgb)

# %%
# Entrenar el modelo con los mejores hiperparámetros
xgb_model_best.fit(X_train_lasso, y_train_lasso,
                   eval_set=[(X_test_lasso, y_test_lasso)],
                   early_stopping_rounds=10,
                   verbose=False)
# Out:
# /opt/miniconda3/envs/py312/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6299749314271313, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=0.22662042341441552,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.02938957066579028,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=466, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizar predicciones en el conjunto de entrenamiento
train_predictions = xgb_model_best.predict(X_train_lasso)

# Realizar predicciones en el conjunto de prueba
test_predictions = xgb_model_best.predict(X_test_lasso)

# %%
# Evaluar el modelo en el conjunto de entrenamiento
train_r2 = r2_score(y_train_lasso, train_predictions)
train_mse = mean_squared_error(y_train_lasso, train_predictions)
train_rmse = np.sqrt(train_mse)

print(f"R2 en el conjunto de entrenamiento: {train_r2:.3f}")
print(f"MSE en el conjunto de entrenamiento: {train_mse:.2f}")
print(f"RMSE en el conjunto de entrenamiento: {train_rmse:.2f}")
# Out:
# R2 en el conjunto de entrenamiento: 0.972
# MSE en el conjunto de entrenamiento: 11133612.06
# RMSE en el conjunto de entrenamiento: 3336.71

# %%
# Evaluar el modelo en el conjunto de prueba
test_r2 = r2_score(y_test_lasso, test_predictions)
test_mse = mean_squared_error(y_test_lasso, test_predictions)
test_rmse = np.sqrt(test_mse)

print(f"R2 en el conjunto de prueba: {test_r2:.3f}")
print(f"MSE en el conjunto de prueba: {test_mse:.2f}")
print(f"RMSE en el conjunto de prueba: {test_rmse:.2f}")
# Out:
# R2 en el conjunto de prueba: 0.687
# MSE en el conjunto de prueba: 121671579.51
# RMSE en el conjunto de prueba: 11030.48
